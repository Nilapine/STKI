# %% [markdown]
# # Studi Kasus 1
# # Projek klasifikasi Sentimen Analisis

# %% [markdown]
# ## Klasifikasi Sentimen Analisis

# %% [markdown]
# Klasifikasi dapat berbentuk berupa Sentimen Analisis. Sentimen Analisis merupakan gabungan dari data mining dan text mining. Secara sederhananya merupakan proses mengolah berbagai opini dan argumen dari berbagai media sosial dalam berbagai aspek seperti jasa, produk, atau sesuai dengan isi konten pada media sosial tersebut .
#
# Untuk dapat mengerjakan sebuah sentimen analisis, diperlukan sebuah dataset yang berisi banyak opini positif, negatif, dan atau netral. Maka dari itu pengambilan dataset merupakan proses yang penting dalam tahapan sentimen analisis. Dataset yang baik harus memiliki ukuran yang cukup besar dengan jumlah yang cukup banyak untuk meminimalkan kesalahan secara perhitungan algoritma.
#
# Untuk mendapatkan sebuah dataset yang berisikan opini di media sosial dapat dilakukan dengan berbagai cara. Salah satunya adalah mencari dataset yang sudah jadi pada situs penyedia dataset seperti kaggle, dataset tersebut dapat dikategorikan sebagai dataset publik. Selain dengan menggunakan dataset publik, data opini dapat dibuat dengan cara scraping atau crawling. Scraping merupakan teknik yang sering digunakan untuk mendapatkan atau mengekstrak sebuah informasi pada sebuah media sosial dan atau website secara otomatis tanpa harus melakukan penyalinan secara manual.
#
# ## Mencari Data Manual dengan Scraping
# Berikut adalah cara mendapatkan data untuk sentimen analisis menggunakan Komentar Youtube. Dapat menggunakan API Key berikut AIzaSyDkCRF4cmM_TtyBznV9aKptHNZqooyucqU

# %%
# yang harus di instal

# !pip install google-api-python-client
# !pip install google-auth google-auth-oauthlib google-auth-httplib2
# !pip install pickle
# !pip install sastrawi
# !pip install textblob
# Out:
# Requirement already satisfied: google-api-python-client in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (2.154.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client) (2.36.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client) (2.23.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.66.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (4.25.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.25.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client) (3.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2024.2.2)
# Requirement already satisfied: google-auth in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (2.36.0)
# Collecting google-auth-oauthlib
#   Downloading google_auth_oauthlib-1.2.1-py2.py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: google-auth-httplib2 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (0.2.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from google-auth) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from google-auth) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from google-auth) (4.9)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: httplib2>=0.19.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from google-auth-httplib2) (0.22.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from httplib2>=0.19.0->google-auth-httplib2) (3.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth) (0.6.1)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib)
#   Downloading oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: requests>=2.0.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2024.2.2)
# Downloading google_auth_oauthlib-1.2.1-py2.py3-none-any.whl (24 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Installing collected packages: oauthlib, requests-oauthlib, google-auth-oauthlib
# Successfully installed google-auth-oauthlib-1.2.1 oauthlib-3.2.2 requests-oauthlib-2.0.0
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle
# Requirement already satisfied: sastrawi in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (1.0.1)
# Collecting textblob
#   Downloading textblob-0.18.0.post0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: nltk>=3.8 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from nltk>=3.8->textblob) (8.1.7)
# Requirement already satisfied: joblib in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from nltk>=3.8->textblob) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from nltk>=3.8->textblob) (2023.12.25)
# Requirement already satisfied: tqdm in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from nltk>=3.8->textblob) (4.66.2)
# Requirement already satisfied: colorama in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from click->nltk>=3.8->textblob) (0.4.6)
# Downloading textblob-0.18.0.post0-py3-none-any.whl (626 kB)
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.3 kB ? eta -:--:--
#    ---------------------------------------- 626.3/626.3 kB 1.4 MB/s eta 0:00:00
# Installing collected packages: textblob
# Successfully installed textblob-0.18.0.post0

# %% [markdown]
# Code diatas merupakan library yang harus terintal.

# %%
pip install --upgrade numpy
# Out:
# Requirement already satisfied: numpy in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (2.0.2)Note: you may need to restart the kernel to use updated packages.
#
# Collecting numpy
#   Downloading numpy-2.1.3-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Downloading numpy-2.1.3-cp312-cp312-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.6 MB 1.3 MB/s eta 0:00:10
#    -- ------------------------------------- 0.8/12.6 MB 1.5 MB/s eta 0:00:08
#    --- ------------------------------------ 1.0/12.6 MB 1.4 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.6/12.6 MB 1.4 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.8/12.6 MB 1.4 MB/s eta 0:00:08
#    ------ --------------------------------- 2.1/12.6 MB 1.3 MB/s eta 0:00:08
#    ------ --------------------------------- 2.1/12.6 MB 1.3 MB/s eta 0:00:08
#    -------- ------------------------------- 2.6/12.6 MB 1.3 MB/s eta 0:00:08
#    --------- ------------------------------ 2.9/12.6 MB 1.3 MB/s eta 0:00:08
#    ---------- ----------------------------- 3.1/12.6 MB 1.3 MB/s eta 0:00:08
#    ---------- ----------------------------- 3.4/12.6 MB 1.3 MB/s eta 0:00:08
#    ----------- ---------------------------- 3.7/12.6 MB 1.3 MB/s eta 0:00:07
#    ------------ --------------------------- 3.9/12.6 MB 1.3 MB/s eta 0:00:07
#    ------------- -------------------------- 4.2/12.6 MB 1.3 MB/s eta 0:00:07
#    -------------- ------------------------- 4.5/12.6 MB 1.3 MB/s eta 0:00:07
#    --------------- ------------------------ 5.0/12.6 MB 1.3 MB/s eta 0:00:06
#    --------------- ------------------------ 5.0/12.6 MB 1.3 MB/s eta 0:00:06
#    ----------------- ---------------------- 5.5/12.6 MB 1.3 MB/s eta 0:00:06
#    ------------------ --------------------- 5.8/12.6 MB 1.3 MB/s eta 0:00:06
#    ------------------- -------------------- 6.0/12.6 MB 1.3 MB/s eta 0:00:05
#    -------------------- ------------------- 6.3/12.6 MB 1.3 MB/s eta 0:00:05
#    -------------------- ------------------- 6.6/12.6 MB 1.3 MB/s eta 0:00:05
#    -------------------- ------------------- 6.6/12.6 MB 1.3 MB/s eta 0:00:05
#    --------------------- ------------------ 6.8/12.6 MB 1.3 MB/s eta 0:00:05
#    ---------------------- ----------------- 7.1/12.6 MB 1.3 MB/s eta 0:00:05
#    ----------------------- ---------------- 7.3/12.6 MB 1.3 MB/s eta 0:00:05
#    ------------------------ --------------- 7.6/12.6 MB 1.3 MB/s eta 0:00:04
#    ------------------------- -------------- 7.9/12.6 MB 1.3 MB/s eta 0:00:04
#    ------------------------- -------------- 8.1/12.6 MB 1.3 MB/s eta 0:00:04
#    -------------------------- ------------- 8.4/12.6 MB 1.3 MB/s eta 0:00:04
#    --------------------------- ------------ 8.7/12.6 MB 1.3 MB/s eta 0:00:04
#    ---------------------------- ----------- 8.9/12.6 MB 1.3 MB/s eta 0:00:03
#    ----------------------------- ---------- 9.2/12.6 MB 1.3 MB/s eta 0:00:03
#    ------------------------------ --------- 9.4/12.6 MB 1.3 MB/s eta 0:00:03
#    ------------------------------ --------- 9.7/12.6 MB 1.3 MB/s eta 0:00:03
#    ------------------------------- -------- 10.0/12.6 MB 1.3 MB/s eta 0:00:03
#    -------------------------------- ------- 10.2/12.6 MB 1.3 MB/s eta 0:00:02
#    --------------------------------- ------ 10.5/12.6 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 10.7/12.6 MB 1.3 MB/s eta 0:00:02
#    ----------------------------------- ---- 11.0/12.6 MB 1.3 MB/s eta 0:00:02
#    ------------------------------------ --- 11.5/12.6 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 11.5/12.6 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 12.1/12.6 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.6 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.6 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.6 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 1.2 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# Successfully installed numpy-2.1.3
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Nila Farihah\AppData\Local\Programs\Python\Python312\Lib\site-packages\~-mpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Nila Farihah\AppData\Local\Programs\Python\Python312\Lib\site-packages\~-mpy'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# contourpy 1.2.0 requires numpy<2.0,>=1.20, but you have numpy 2.1.3 which is incompatible.
# matplotlib 3.8.3 requires numpy<2,>=1.21, but you have numpy 2.1.3 which is incompatible.
# pandas 2.2.1 requires numpy<2,>=1.26.0; python_version >= "3.12", but you have numpy 2.1.3 which is incompatible.
# scikit-learn 1.4.1.post1 requires numpy<2.0,>=1.19.5, but you have numpy 2.1.3 which is incompatible.
# scipy 1.12.0 requires numpy<1.29.0,>=1.22.4, but you have numpy 2.1.3 which is incompatible.
# tensorflow-intel 2.16.1 requires numpy<2.0.0,>=1.26.0; python_version >= "3.12", but you have numpy 2.1.3 which is incompatible.
# thinc 8.3.2 requires numpy<2.1.0,>=2.0.0; python_version >= "3.9", but you have numpy 2.1.3 which is incompatible.

# %%
pip install --upgrade pandas pandasai
# Out:
# Requirement already satisfied: pandas in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (2.2.1)
# Collecting pandas
#   Downloading pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting pandasai
#   Downloading pandasai-2.4.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Collecting astor<0.9.0,>=0.8.1 (from pandasai)
#   Downloading astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting duckdb<2.0.0,>=1.0.0 (from pandasai)
#   Downloading duckdb-1.1.3-cp312-cp312-win_amd64.whl.metadata (781 bytes)
# Collecting faker<20.0.0,>=19.12.0 (from pandasai)
#   Downloading Faker-19.13.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.3 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from pandasai) (3.1.3)
# Requirement already satisfied: matplotlib<4.0.0,>=3.7.1 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from pandasai) (3.8.3)
# Collecting openai<2 (from pandasai)
#   Downloading openai-1.56.0-py3-none-any.whl.metadata (24 kB)
# Collecting pandas
#   Downloading pandas-1.5.3.tar.gz (5.2 MB)
#      ---------------------------------------- 0.0/5.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/5.2 MB ? eta -:--:--
#      -- ------------------------------------- 0.3/5.2 MB ? eta -:--:--
#      -- ------------------------------------- 0.3/5.2 MB ? eta -:--:--
#      ---- ----------------------------------- 0.5/5.2 MB 699.0 kB/s eta 0:00:07
#      ------ --------------------------------- 0.8/5.2 MB 730.2 kB/s eta 0:00:07
#      ------ --------------------------------- 0.8/5.2 MB 730.2 kB/s eta 0:00:07
#      -------- ------------------------------- 1.0/5.2 MB 812.4 kB/s eta 0:00:06
#      ---------- ----------------------------- 1.3/5.2 MB 871.6 kB/s eta 0:00:05
#      ------------ --------------------------- 1.6/5.2 MB 912.1 kB/s eta 0:00:04
#      -------------- ------------------------- 1.8/5.2 MB 932.3 kB/s eta 0:00:04
#      ---------------- ----------------------- 2.1/5.2 MB 995.7 kB/s eta 0:00:04
#      -------------------- ------------------- 2.6/5.2 MB 1.1 MB/s eta 0:00:03
#      ---------------------- ----------------- 2.9/5.2 MB 1.1 MB/s eta 0:00:03
#      -------------------------- ------------- 3.4/5.2 MB 1.2 MB/s eta 0:00:02
#      ---------------------------- ----------- 3.7/5.2 MB 1.2 MB/s eta 0:00:02
#      -------------------------------- ------- 4.2/5.2 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------- ----- 4.5/5.2 MB 1.3 MB/s eta 0:00:01
#      -------------------------------------- - 5.0/5.2 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------- 5.2/5.2 MB 1.3 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: still running...
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: pillow<11.0.0,>=10.1.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from pandasai) (10.2.0)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from pandasai) (2.10.2)
# Collecting python-dotenv<2.0.0,>=1.0.0 (from pandasai)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from pandasai) (2.31.0)
# Requirement already satisfied: scipy<2.0.0,>=1.9.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from pandasai) (1.12.0)
# Collecting sqlalchemy<3,>=1.4 (from pandasai)
#   Downloading SQLAlchemy-2.0.36-cp312-cp312-win_amd64.whl.metadata (9.9 kB)
# Collecting sqlglot<26.0.0,>=25.0.3 (from sqlglot[rs]<26.0.0,>=25.0.3->pandasai)
#   Downloading sqlglot-25.32.1-py3-none-any.whl.metadata (19 kB)
# Collecting torch==2.4.1 (from pandasai)
#   Downloading torch-2.4.1-cp312-cp312-win_amd64.whl.metadata (27 kB)
# Requirement already satisfied: filelock in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from torch==2.4.1->pandasai) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from torch==2.4.1->pandasai) (4.12.2)
# Requirement already satisfied: sympy in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from torch==2.4.1->pandasai) (1.13.1)
# Requirement already satisfied: networkx in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from torch==2.4.1->pandasai) (3.4.2)
# Requirement already satisfied: fsspec in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from torch==2.4.1->pandasai) (2024.10.0)
# Requirement already satisfied: setuptools in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from torch==2.4.1->pandasai) (70.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from jinja2<4.0.0,>=3.1.3->pandasai) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (1.4.5)
# Collecting numpy>=1.21.0 (from pandas)
#   Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (3.1.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from openai<2->pandasai) (4.3.0)
# Collecting distro<2,>=1.7.0 (from openai<2->pandasai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from openai<2->pandasai) (0.27.0)
# Collecting jiter<1,>=0.4.0 (from openai<2->pandasai)
#   Downloading jiter-0.8.0-cp312-none-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: sniffio in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from openai<2->pandasai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from openai<2->pandasai) (4.66.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1->pandasai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1->pandasai) (2.27.1)
# Requirement already satisfied: six>=1.5 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.31.0->pandasai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.31.0->pandasai) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.31.0->pandasai) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.31.0->pandasai) (2024.2.2)
# Collecting greenlet!=0.4.17 (from sqlalchemy<3,>=1.4->pandasai)
#   Downloading greenlet-3.1.1-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# Collecting sqlglotrs==0.3.0 (from sqlglot[rs]<26.0.0,>=25.0.3->pandasai)
#   Downloading sqlglotrs-0.3.0-cp312-none-win_amd64.whl.metadata (545 bytes)
# Requirement already satisfied: httpcore==1.* in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->openai<2->pandasai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2->pandasai) (0.14.0)
# Requirement already satisfied: colorama in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from tqdm>4->openai<2->pandasai) (0.4.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from sympy->torch==2.4.1->pandasai) (1.3.0)
# Downloading pandasai-2.4.0-py3-none-any.whl (193 kB)
# Downloading torch-2.4.1-cp312-cp312-win_amd64.whl (199.4 MB)
#    ---------------------------------------- 0.0/199.4 MB ? eta -:--:--
#    ---------------------------------------- 0.3/199.4 MB ? eta -:--:--
#    ---------------------------------------- 0.8/199.4 MB 1.7 MB/s eta 0:01:59
#    ---------------------------------------- 1.0/199.4 MB 1.4 MB/s eta 0:02:22
#    ---------------------------------------- 1.3/199.4 MB 1.3 MB/s eta 0:02:28
#    ---------------------------------------- 1.3/199.4 MB 1.3 MB/s eta 0:02:28
#    ---------------------------------------- 1.8/199.4 MB 1.4 MB/s eta 0:02:26
#    ---------------------------------------- 2.1/199.4 MB 1.3 MB/s eta 0:02:30
#    ---------------------------------------- 2.4/199.4 MB 1.4 MB/s eta 0:02:21
#     --------------------------------------- 2.6/199.4 MB 1.4 MB/s eta 0:02:20
#     --------------------------------------- 3.1/199.4 MB 1.5 MB/s eta 0:02:16
#     --------------------------------------- 3.4/199.4 MB 1.5 MB/s eta 0:02:14
#     --------------------------------------- 3.9/199.4 MB 1.5 MB/s eta 0:02:12
#     --------------------------------------- 4.2/199.4 MB 1.5 MB/s eta 0:02:11
#     --------------------------------------- 4.5/199.4 MB 1.5 MB/s eta 0:02:12
#     --------------------------------------- 5.0/199.4 MB 1.5 MB/s eta 0:02:07
#    - -------------------------------------- 5.2/199.4 MB 1.6 MB/s eta 0:02:05
#    - -------------------------------------- 5.5/199.4 MB 1.6 MB/s eta 0:02:04
#    - -------------------------------------- 5.5/199.4 MB 1.6 MB/s eta 0:02:04
#    - -------------------------------------- 5.5/199.4 MB 1.6 MB/s eta 0:02:04
#    - -------------------------------------- 5.5/199.4 MB 1.6 MB/s eta 0:02:04
#    - -------------------------------------- 5.5/199.4 MB 1.6 MB/s eta 0:02:04
#    - -------------------------------------- 5.5/199.4 MB 1.6 MB/s eta 0:02:04
#    - -------------------------------------- 5.8/199.4 MB 1.2 MB/s eta 0:02:47
#    --------------------- ---------------- 112.5/199.4 MB 920.4 kB/s eta 0:01:35
#    --------------------- ---------------- 113.0/199.4 MB 926.2 kB/s eta 0:01:34
#    --------------------- ---------------- 113.2/199.4 MB 926.2 kB/s eta 0:01:34
#    --------------------- ---------------- 113.5/199.4 MB 927.2 kB/s eta 0:01:33
#    --------------------- ---------------- 114.0/199.4 MB 923.3 kB/s eta 0:01:33
#    --------------------- ---------------- 114.3/199.4 MB 927.7 kB/s eta 0:01:32
#    --------------------- ---------------- 114.8/199.4 MB 932.1 kB/s eta 0:01:31
#    --------------------- ---------------- 115.1/199.4 MB 936.9 kB/s eta 0:01:30
#    ---------------------- --------------- 115.6/199.4 MB 935.5 kB/s eta 0:01:30
#    ---------------------- --------------- 115.9/199.4 MB 938.9 kB/s eta 0:01:29
#    ---------------------- --------------- 116.4/199.4 MB 945.2 kB/s eta 0:01:28
#    ---------------------- --------------- 116.7/199.4 MB 945.2 kB/s eta 0:01:28
#    ---------------------- --------------- 117.2/199.4 MB 950.6 kB/s eta 0:01:27
#    ---------------------- --------------- 117.7/199.4 MB 957.4 kB/s eta 0:01:26
#    ---------------------- --------------- 118.0/199.4 MB 958.5 kB/s eta 0:01:25
# ...
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   C:\Users\Nila Farihah\AppData\Local\Temp\pip-build-env-avp21_3f\overlay\Lib\site-packages\setuptools\command\build_py.py:212: _Warning: Package 'pandas.tests.io.data.xml' is absent from the `packages` configuration.
#   !!
#
#           ********************************************************************************
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pandas.tests.io.data.xml' as an importable package[^1],
#           but it is absent from setuptools' `packages` configuration.
#
#           This leads to an ambiguous overall configuration. If you want to distribute this
#           package, please make sure that 'pandas.tests.io.data.xml' is explicitly added
#           to the `packages` configuration field.
#
#           Alternatively, you can also rely on setuptools' discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#           If you don't want 'pandas.tests.io.data.xml' to be distributed and are
#           already explicitly excluding 'pandas.tests.io.data.xml' via
#           `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#           you can try to use `exclude_package_data`, or `include-package-data=False` in
#           combination with a more fine grained `package-data` configuration.
#
#           You can read more about "package data files" on setuptools documentation page:
#
#           - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#           [^1]: For Python, any directory (with suitable naming) can be imported,
#                 even if it does not contain any `.py` files.
#                 On the other hand, currently there is no concept of package data
#                 directory, all directories are treated like packages.
#           ********************************************************************************
#
#   !!
#     check.warn(importable)
#   copying pandas\_libs\algos_common_helper.pxi.in -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\algos_take_helper.pxi.in -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\hashtable_class_helper.pxi.in -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\hashtable_func_helper.pxi.in -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\index_class_helper.pxi.in -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\intervaltree.pxi.in -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\khash_for_primitive_helper.pxi.in -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\sparse_op_helper.pxi.in -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\algos.pxd -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\algos.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\algos.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\arrays.pxd -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\arrays.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\arrays.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\dtypes.pxd -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\groupby.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\groupby.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\hashing.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\hashing.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\hashtable.pxd -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\hashtable.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\hashtable.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\index.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\index.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\indexing.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\indexing.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\internals.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\internals.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\interval.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\interval.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\join.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\join.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\json.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\khash.pxd -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\lib.pxd -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\lib.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\lib.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\missing.pxd -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\missing.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\missing.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\ops.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\ops.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\ops_dispatch.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\ops_dispatch.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\parsers.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\parsers.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\properties.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\properties.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\reduction.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\reduction.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\reshape.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\reshape.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\sparse.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\sparse.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\testing.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\testing.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\tslib.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\tslib.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\util.pxd -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\writers.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs
#   copying pandas\_libs\writers.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs
#   creating build\lib.win-amd64-cpython-312\pandas\io\formats\templates
#   copying pandas\io\formats\templates\html.tpl -> build\lib.win-amd64-cpython-312\pandas\io\formats\templates
#   copying pandas\io\formats\templates\html_style.tpl -> build\lib.win-amd64-cpython-312\pandas\io\formats\templates
#   copying pandas\io\formats\templates\html_table.tpl -> build\lib.win-amd64-cpython-312\pandas\io\formats\templates
#   copying pandas\io\formats\templates\latex.tpl -> build\lib.win-amd64-cpython-312\pandas\io\formats\templates
#   copying pandas\io\formats\templates\latex_longtable.tpl -> build\lib.win-amd64-cpython-312\pandas\io\formats\templates
#   copying pandas\io\formats\templates\latex_table.tpl -> build\lib.win-amd64-cpython-312\pandas\io\formats\templates
#   copying pandas\io\formats\templates\string.tpl -> build\lib.win-amd64-cpython-312\pandas\io\formats\templates
#   copying pandas\io\sas\_sas.pyi -> build\lib.win-amd64-cpython-312\pandas\io\sas
#   copying pandas\io\sas\sas.pyx -> build\lib.win-amd64-cpython-312\pandas\io\sas
#   creating build\lib.win-amd64-cpython-312\pandas\tests\io\data
#   copying pandas\tests\io\data\gbq_fake_job.txt -> build\lib.win-amd64-cpython-312\pandas\tests\io\data
#   creating build\lib.win-amd64-cpython-312\pandas\tests\io\data\fixed_width
#   copying pandas\tests\io\data\fixed_width\fixed_width_format.txt -> build\lib.win-amd64-cpython-312\pandas\tests\io\data\fixed_width
#   creating build\lib.win-amd64-cpython-312\pandas\tests\io\data\legacy_pickle\1.2.4
#   copying pandas\tests\io\data\legacy_pickle\1.2.4\empty_frame_v1_2_4-GH#42345.pkl -> build\lib.win-amd64-cpython-312\pandas\tests\io\data\legacy_pickle\1.2.4
#   creating build\lib.win-amd64-cpython-312\pandas\tests\io\data\parquet
#   copying pandas\tests\io\data\parquet\simple.parquet -> build\lib.win-amd64-cpython-312\pandas\tests\io\data\parquet
#   creating build\lib.win-amd64-cpython-312\pandas\tests\io\data\pickle
#   copying pandas\tests\io\data\pickle\test_mi_py27.pkl -> build\lib.win-amd64-cpython-312\pandas\tests\io\data\pickle
#   copying pandas\tests\io\data\pickle\test_py27.pkl -> build\lib.win-amd64-cpython-312\pandas\tests\io\data\pickle
#   creating build\lib.win-amd64-cpython-312\pandas\tests\io\data\xml
#   copying pandas\tests\io\data\xml\baby_names.xml -> build\lib.win-amd64-cpython-312\pandas\tests\io\data\xml
#   copying pandas\tests\io\data\xml\books.xml -> build\lib.win-amd64-cpython-312\pandas\tests\io\data\xml
#   copying pandas\tests\io\data\xml\cta_rail_lines.kml -> build\lib.win-amd64-cpython-312\pandas\tests\io\data\xml
#   copying pandas\tests\io\data\xml\doc_ch_utf.xml -> build\lib.win-amd64-cpython-312\pandas\tests\io\data\xml
#   copying pandas\tests\io\data\xml\flatten_doc.xsl -> build\lib.win-amd64-cpython-312\pandas\tests\io\data\xml
#   copying pandas\tests\io\data\xml\row_field_output.xsl -> build\lib.win-amd64-cpython-312\pandas\tests\io\data\xml
#   copying pandas\_libs\tslibs\base.pxd -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\base.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\ccalendar.pxd -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\ccalendar.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\ccalendar.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\conversion.pxd -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\conversion.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\conversion.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\dtypes.pxd -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\dtypes.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\dtypes.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\fields.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\fields.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\nattype.pxd -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\nattype.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\nattype.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\np_datetime.pxd -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\np_datetime.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\np_datetime.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\offsets.pxd -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\offsets.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\offsets.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\parsing.pxd -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\parsing.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\parsing.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\period.pxd -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\period.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\period.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\strptime.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\strptime.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\timedeltas.pxd -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\timedeltas.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\timedeltas.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\timestamps.pxd -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\timestamps.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\timestamps.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\timezones.pxd -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\timezones.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\timezones.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\tzconversion.pxd -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\tzconversion.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\tzconversion.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\util.pxd -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\vectorized.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\tslibs\vectorized.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs\tslibs
#   copying pandas\_libs\window\aggregations.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs\window
#   copying pandas\_libs\window\aggregations.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs\window
#   copying pandas\_libs\window\indexers.pyi -> build\lib.win-amd64-cpython-312\pandas\_libs\window
#   copying pandas\_libs\window\indexers.pyx -> build\lib.win-amd64-cpython-312\pandas\_libs\window
#   UPDATING build\lib.win-amd64-cpython-312\pandas/_version.py
#   set build\lib.win-amd64-cpython-312\pandas/_version.py to '1.5.3'
#   running build_ext
#   building 'pandas._libs.algos' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pandas
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (pandas)

# %%
pip install numpy==1.26.4  pyyaml
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting numpy==1.26.4
#   Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Requirement already satisfied: pyyaml in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (6.0.1)
# Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.3
#     Uninstalling numpy-2.1.3:
#       Successfully uninstalled numpy-2.1.3
# Successfully installed numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# blis 1.0.1 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# thinc 8.3.2 requires numpy<2.1.0,>=2.0.0; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.

# %%
#library yang digunakan, jika dirasa kurang penting dapat dihapus
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import string
import re
from nltk import word_tokenize
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from wordcloud import WordCloud, STOPWORDS
from sklearn.metrics import ConfusionMatrixDisplay
from textblob import TextBlob
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Nila
# [nltk_data]     Farihah\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Nila
# [nltk_data]     Farihah\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Setalah mengimport semua library, selanjutnya measukan code berikut

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import pandas as pd

## Call the "build()" function from the Python-client
from googleapiclient.discovery import build

api_key = input("API KEY: ")
youtube = build("youtube","v3", developerKey=api_key)
url = input("VIDEOURL: ")

def get_comments(url):
    # Get the ID of the video by splitting the URL
    single_video_id = url.split("=")[1].split("&")[0]
    # Use the list() method to extract a JSON with key information
    # from the video.
    video_list=youtube.videos().list(part="snippet",id=single_video_id).execute()
    channel_id= video_list["items"][0]["snippet"]["channelId"]
    title_single_video= video_list["items"][0]["snippet"]["title"]
    playlist_id = None
    forUserName = None

    nextPageToken_comments = None
    commentsone=[]

    while True:
        #Request the first 50 videos of a channel. This is the full dictionary. The result is store in a variable called "pl_response".
        #PageToken at this point is "None"
        pl_request_comment= youtube.commentThreads().list(part=["snippet","replies"],
                                            videoId=single_video_id,
                                            maxResults=50,
                                            pageToken= nextPageToken_comments)
        pl_response_comment = pl_request_comment.execute()

        ## Send the amount of views and the URL of each video to the videos empty list that was declared at the beginning of the code.
        for i in pl_response_comment["items"]:
            vid_comments = i["snippet"]["topLevelComment"]["snippet"]["textOriginal"]
            comm_author = i["snippet"]["topLevelComment"]["snippet"]["authorDisplayName"]
            comm_author_id = i["snippet"]["topLevelComment"]["snippet"]["authorChannelId"]["value"]
            comm_date = i["snippet"]["topLevelComment"]["snippet"]["publishedAt"]
            comm_likes = i["snippet"]["topLevelComment"]["snippet"]["likeCount"]
            new_var=i.get("replies","0")

            commentsone.append({
                "comm_date":comm_date,
                "author":comm_author,
                "author_id":comm_author_id,
                "likes":comm_likes,
                "comment":vid_comments,
                "video_id":single_video_id
            })



        nextPageToken_comments = pl_response_comment.get("nextPageToken")

        if not nextPageToken_comments:
            break

    for i in commentsone[:10]:
        print(i["comment"])


    pd.DataFrame.from_dict(commentsone).to_csv(f"data/dataset.csv")

get_comments(url)
# Out:
# API KEY:  AIzaSyA7BDBeQUxMoe98wAoh9ThWVjxocWARf54
# VIDEOURL:  https://www.youtube.com/watch?v=f1JdrnJaCos
# Mendadak ngidam nyubit pipinyaaa ka viooor😂😂😂😂
# Selama nonton ini ngga beehenti ketawanya gara gara liat vior
# Baru nyadar tgl upload konten ini bertepatan dengan meninggal nya mamaku😭
# Kesini biar bisa terhibur sedikit malah mewek😭😭😭
# Alfatihah ma🥺
# kynya di episode kali ini, ka Vidi ngambil kursinya bang Onad dah... kena roasting Habib 😂😂... tp gpp ka Vidi, anggep warming up aja sebelum masuk ke Login nanti 😁😁... tp kalo boleh Request, login tahun depan, episode ka Vidi bareng om Ded donk... biar balesan dari Login ke podhub kmrn, sekarang Podhub yg ke Login 😁😁🤲🤲
# Cape bgt 😭
# ini gokil banget, polos sih ini tapi sok ngide lucu akrab nyaman lanjut
# Sehat-sehit, lika-liku, bolak-balik. Malah jd kata baru sama vior 😂😂
# Baru kali ini lihat podhub dr awal sampai akhir  ngakak terus...benar2 menghibur, utk salanjutx undang lagi  habib jafar dan fior setelah nikah dong 🙏🙏🙏
# sabar ya om ded😅
# Bahasa nya perempuan konon nya bodoh pada hal gak punya malu.

# %% [markdown]
# pada source code scraping diatas, file yang telah di scraping akan dimasukan kedalam Google Drive dengan nama file comments, lalu nama file akan menjadi dataset.csv
#
# untuk menampilkan hasil scraping dapat menggunakan perintah seperti berikut.

# %%
df = pd.read_csv('data/dataset.csv')
df.head(500)
df.count()
# Out:
# Unnamed: 0    6488
# comm_date     6488
# author        6488
# author_id     6488
# likes         6488
# comment       6488
# video_id      6488
# dtype: int64

# %% [markdown]
# ### Mencari Data dengan mengunjungi website
# Data sentimen analisis bisa didapatkan melalui website penyedia data seperti kaggle dan UC Irvine Machine Learning Repository.
#
# ### Sentimen Analisis menggunakan data scraping youtube
# gunakan code berikut untuk melakukan sentimen analisis

# %%
import nltk
import pandas as pd
data = pd.read_csv("data/dataset.csv")
data = data.dropna()
print(data.head())
# Out:
#    Unnamed: 0             comm_date                     author  \
# 0           0  2024-12-26T01:43:15Z                @AMIRZAOPPA
# 1           1  2024-12-26T01:34:30Z         @resitaaprilia2934
# 2           2  2024-12-26T01:27:59Z          @windarahayuputri
# 3           3  2024-12-26T01:26:58Z  @muhammadkhairunnizar3841
# 4           4  2024-12-26T01:19:25Z            @AyuNingrum-y3u
#
#                   author_id  likes  \
# 0  UCVpNi23GzK6Ffj1-tniIbWA      0
# 1  UCzFQDWZyFl7BUb802yM_exg      0
# 2  UCvBfZqdfRkNYXQJUEFEg09Q      0
# 3  UCgDZEykZsiAzxVsQh-3fWuw      0
# 4  UC__OkX5_BtHcGt2mW3Uhb8g      0
#
#                                              comment     video_id
# 0     Mendadak ngidam nyubit pipinyaaa ka viooor😂😂😂😂  f1JdrnJaCos
# 1  Selama nonton ini ngga beehenti ketawanya gara...  f1JdrnJaCos
# 2  Baru nyadar tgl upload konten ini bertepatan d...  f1JdrnJaCos
# 3  kynya di episode kali ini, ka Vidi ngambil kur...  f1JdrnJaCos
# 4                                         Cape bgt 😭  f1JdrnJaCos

# %%
data_nw = data.drop(['comm_date',"author", 'author_id',"likes",'video_id'], axis=1 )
data_nw
# Out:
#       Unnamed: 0                                            comment
# 0              0     Mendadak ngidam nyubit pipinyaaa ka viooor😂😂😂😂
# 1              1  Selama nonton ini ngga beehenti ketawanya gara...
# 2              2  Baru nyadar tgl upload konten ini bertepatan d...
# 3              3  kynya di episode kali ini, ka Vidi ngambil kur...
# 4              4                                         Cape bgt 😭
# ...          ...                                                ...
# 6483        6483                                             Mantep
# 6484        6484                                            Pertama
# 6485        6485                                                😂😂😂
# 6486        6486                             yieeeeeyyyy pertamaaaa
# 6487        6487                                                  1
#
# [6488 rows x 2 columns]

# %% [markdown]
# Fungsi code diatas adalah untuk menghapus atau melakukan drop pada kolom ‘comm_date’,“author”, ‘author_id’,“likes”,‘video_id’

# %%
data_nw.to_csv("data/dataset_drop.csv") #Fungsinya untuk menyimpan hasil drop

# %% [markdown]
# membuka file hasil dari dataset_drop.csv

# %%
data_baru = pd.read_csv("data/dataset_drop.csv")
data_baru.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                                            comment
# 0             0           0     Mendadak ngidam nyubit pipinyaaa ka viooor😂😂😂😂
# 1             1           1  Selama nonton ini ngga beehenti ketawanya gara...
# 2             2           2  Baru nyadar tgl upload konten ini bertepatan d...
# 3             3           3  kynya di episode kali ini, ka Vidi ngambil kur...
# 4             4           4                                         Cape bgt 😭

# %%
def caseFolding(comment):
          comment = comment.lower()
          comment = comment.strip(" ")
          comment = re.sub(r'[?|$|.|!]',r'', comment)
          comment = re.sub(r'[^a-zA-Z0-9 ]',r'', comment)
          return comment

data_baru['comment'] = data_baru['comment'].apply(caseFolding)

# %% [markdown]
# Fungsi dari code diatas adalah untuk menghilangkan tanda baca serta angka yang tidak dibutuhkan dan mengubah huruf kapital menjadi huruf kecil. Lalu data disimpan ke dalam kolom comment.
#
# Selanjutnya simpan menggunakan perintah berikut

# %%
data_baru.to_csv("data/dataset_bersih.csv")

# %% [markdown]
# Selanjutnya data yang sudah bersih, dapat diberi label negatif, positif, dan atau netral pada samping kolom comments. Label dapat di beri nama sentiment.
#
# Selanjutnya dapat dilakukan uji akurasi menggunakan Algoritma atau model yang sesuai dan yang di inginkan.
#
# Sebagai contoh menggunakan Algoritma KNN, maka dapat menggunakan code berikut.

# %% [markdown]
# **kolom sentimen dari mana?**

# %%
dataset_baru = pd.read_csv('data/dataset_bersih.csv')

# Mengisi nilai NaN dengan string kosong
dataset_baru['comment'] = dataset_baru['comment'].fillna("")

# Semua Nilai Bertipe String
dataset_baru['comment'] = dataset_baru['comment'].astype(str)

# %%
dataset_baru = list(dataset_baru['comment'])

# Inisialisasi variabel
polaritas = 0
status = []
total_positif = total_negatif = total_netral = total = 0

# Analisis sentimen
for i, tweet in enumerate(dataset_baru):
    analysis = TextBlob(tweet)
    polaritas += analysis.polarity

    # Klasifikasi sentimen berdasarkan polaritas
    if analysis.sentiment.polarity > 0.0:
        total_positif += 1
        status.append('Positif')
    elif analysis.sentiment.polarity == 0.0:
        total_netral += 1
        status.append('Netral')
    else:
        total_negatif += 1
        status.append('Negatif')

    total += 1

# Menambahkan kolom 'sentimen' ke dataset asli
df['sentimen'] = status

# Menyimpan hasil ke file baru
df.to_csv('data/dataset_analisis_sentimen.csv', index=False)

# Output hasil analisis
print(f'Hasil Analisis Data:')
print(f'Positif = {total_positif}')
print(f'Netral = {total_netral}')
print(f'Negatif = {total_negatif}')
print(f'\nTotal Data : {total}')
# Out:
# Hasil Analisis Data:
# Positif = 384
# Netral = 6027
# Negatif = 77
#
# Total Data : 6488

# %%
data = pd.read_csv('data/dataset_analisis_sentimen.csv')
data.head()
# Out:
#    Unnamed: 0             comm_date                     author  \
# 0           0  2024-12-26T01:43:15Z                @AMIRZAOPPA
# 1           1  2024-12-26T01:34:30Z         @resitaaprilia2934
# 2           2  2024-12-26T01:27:59Z          @windarahayuputri
# 3           3  2024-12-26T01:26:58Z  @muhammadkhairunnizar3841
# 4           4  2024-12-26T01:19:25Z            @AyuNingrum-y3u
#
#                   author_id  likes  \
# 0  UCVpNi23GzK6Ffj1-tniIbWA      0
# 1  UCzFQDWZyFl7BUb802yM_exg      0
# 2  UCvBfZqdfRkNYXQJUEFEg09Q      0
# 3  UCgDZEykZsiAzxVsQh-3fWuw      0
# 4  UC__OkX5_BtHcGt2mW3Uhb8g      0
#
#                                              comment     video_id sentimen
# 0     Mendadak ngidam nyubit pipinyaaa ka viooor😂😂😂😂  f1JdrnJaCos   Netral
# 1  Selama nonton ini ngga beehenti ketawanya gara...  f1JdrnJaCos   Netral
# 2  Baru nyadar tgl upload konten ini bertepatan d...  f1JdrnJaCos   Netral
# 3  kynya di episode kali ini, ka Vidi ngambil kur...  f1JdrnJaCos   Netral
# 4                                         Cape bgt 😭  f1JdrnJaCos   Netral

# %%
print(data.columns)
# Out:
# Index(['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', 'comment'], dtype='object')

# %%
X = data['comment']
y = data['sentimen']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sentimen'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 2
#       1 X = data['comment']
# ----> 2 y = data['sentimen']
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'sentimen'

# %%
import pandas as pd

data = pd.read_csv('data/dataset_bersih.csv')
X = data['comment']
y = data['sentimen']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sentimen'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 5
#       3 data = pd.read_csv('data/dataset_bersih.csv')
#       4 X = data['comment']
# ----> 5 y = data['sentimen']
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'sentimen'
